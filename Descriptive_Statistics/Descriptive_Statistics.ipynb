# %% [markdown]
# # **Descriptive Statistics**

# %% [markdown]
# ## Importing the Dependencies

# %% [markdown]
# ```python
# import numpy as np
# import pandas as pd
# from scipy import stats
# import statistics
# import seaborn as sns
# import statsmodels.api as sm
# from seaborn_qqplot import pplot
# import matplotlib.pyplot as plt
# %matplotlib inline
# ```

# %% [markdown]
# Data collection

# %% [markdown]
# ``` python
# Data = pd.read_csv("/content/data.csv")
# ```

# %% [markdown]
# ``` python
# display(Data)
# ```
# |index|Mthly\_HH\_Income|Mthly\_HH\_Expense|No\_of\_Fly\_Members|Emi\_or\_Rent\_Amt|Annual\_HH\_Income|Highest\_Qualified\_Member|No\_of\_Earning\_Members|
# |---|---|---|---|---|---|---|---|
# |0|5000|8000|3|2000|64200|Under-Graduate|1|
# |1|6000|7000|2|3000|79920|Illiterate|1|
# |2|10000|4500|2|0|112800|Under-Graduate|1|
# |3|10000|2000|1|0|97200|Illiterate|1|
# |4|12500|12000|2|3000|147000|Graduate|1|
# |5|14000|8000|2|0|196560|Graduate|1|
# |6|15000|16000|3|35000|167400|Post-Graduate|1|
# |7|18000|20000|5|8000|216000|Graduate|1|
# |8|19000|9000|2|0|218880|Under-Graduate|1|
# |9|20000|9000|4|0|220800|Under-Graduate|2|
# |10|20000|18000|4|8000|278400|Under-Graduate|2|
# |11|22000|25000|6|12000|279840|Illiterate|1|
# |12|23400|5000|3|0|292032|Illiterate|1|
# |13|24000|10500|6|0|316800|Graduate|2|
# |14|24000|10000|4|0|244800|Graduate|2|
# |15|25000|12300|3|0|246000|Graduate|1|
# |16|25000|20000|3|3500|261000|Graduate|1|
# |17|25000|10000|6|0|258000|Under-Graduate|3|
# |18|29000|6600|2|2000|348000|Graduate|1|
# |19|30000|13000|4|0|385200|Graduate|1|
# |20|30500|25000|5|5000|351360|Under-Graduate|1|
# |21|32000|15000|4|0|445440|Professional|1|
# |22|34000|19000|6|0|330480|Professional|1|
# |23|34000|25000|3|4000|469200|Professional|1|
# |24|35000|12000|3|0|466200|Graduate|1|
# |25|35000|25000|4|0|449400|Professional|2|
# |26|39000|8000|4|0|556920|Under-Graduate|1|
# |27|40000|10000|4|0|412800|Under-Graduate|1|
# |28|42000|15000|4|0|488880|Graduate|1|
# |29|43000|12000|4|0|619200|Graduate|1|
# |30|45000|25000|6|0|523800|Graduate|3|
# |31|45000|40000|6|3500|507600|Professional|2|
# |32|45000|10000|2|1000|437400|Post-Graduate|1|
# |33|45000|22000|4|2500|610200|Post-Graduate|1|
# |34|46000|25000|5|3500|596160|Graduate|1|
# |35|47000|15000|7|0|456840|Professional|4|
# |36|50000|20000|4|0|570000|Professional|1|
# |37|50500|20000|3|0|581760|Professional|2|
# |38|55000|45000|6|12000|600600|Graduate|2|
# |39|60000|10000|3|0|590400|Post-Graduate|1|
# |40|60000|50000|6|10000|590400|Graduate|1|
# |41|65000|20000|4|5000|647400|Illiterate|2|
# |42|70000|9000|2|0|756000|Graduate|1|
# |43|80000|20000|4|0|1075200|Graduate|1|
# |44|85000|25000|5|0|1142400|Under-Graduate|2|
# |45|90000|48000|7|0|885600|Post-Graduate|3|
# |46|98000|25000|5|0|1152480|Professional|2|
# |47|100000|30000|6|0|1404000|Graduate|3|
# |48|100000|50000|4|20000|1032000|Professional|2|
# |49|100000|40000|6|10000|1320000|Post-Graduate|1|

# %% [markdown]
# ```python
# Data.describe()
# ```
# |index|Mthly\_HH\_Income|Mthly\_HH\_Expense|No\_of\_Fly\_Members|Emi\_or\_Rent\_Amt|Annual\_HH\_Income|No\_of\_Earning\_Members|
# |---|---|---|---|---|---|---|
# |count|50\.0|50\.0|50\.0|50\.0|50\.0|50\.0|
# |mean|41558\.0|18818\.0|4\.06|3060\.0|490019\.04|1\.46|
# |std|26097\.908978713687|12090\.216824240286|1\.5173822786601394|6241\.434947516607|320135\.7921225253|0\.7342912729083655|
# |min|5000\.0|2000\.0|1\.0|0\.0|64200\.0|1\.0|
# |25%|23550\.0|10000\.0|3\.0|0\.0|258750\.0|1\.0|
# |50%|35000\.0|15500\.0|4\.0|0\.0|447420\.0|1\.0|
# |75%|50375\.0|25000\.0|5\.0|3500\.0|594720\.0|2\.0|
# |max|100000\.0|50000\.0|7\.0|35000\.0|1404000\.0|4\.0|

# %% [markdown]
# ## **1. Mean**
#
# The mean is the most widely spread
# measure of central tendency. It is the
# simple average of the dataset.
#
# Note: easily affected by outliers
#
# >The formula to calculate the mean is:
#
# $$ Mean = \overline{\rm 𝓧} = \frac{\Sigma^{N}_{i=1} x_{i}}{N}\\ $$
#
# $$ or $$
#
# $$ \frac{𝑥_{1} + 𝑥_{2} + 𝑥_{3} + ⋯ + 𝑥_{𝑁−1} + 𝑥_{N}}{N} $$
#
# >calculate mean Using Numpy Libraries
# ``` python
# np.mean(Data, axis=0)
# ```
# >calualte mean Using Pandas Libraries
# ``` python
# Data.mean(axis=0)
# ```
# ### Result:
# | ID | Label | Mean |
# | --- | --- | --- |
# | 1 | Mthly_HH_Income | 41558.00 |
# | 2 | Mthly_HH_Expense | 18818.00 |
# | 3 | No_of_Fly_Members | 4.06 |
# | 4 | Emi_or_Rent_Amt | 3060.00 |
# | 5 | Annual_HH_Income | 490019.04 |
# | 6 | No_of_Earning_Members | 1.46 |
# dtype: float64

# %% [markdown]
# ##**2. Median**
#
# The median is the midpoint of the
# ordered dataset. It is not as popular as
# the mean, but is often used in
# academia and data science. That is
# since it is not affected by outliers.
#
# Median formula is different for even and odd numbers of observations.
#
# > The Formula to Calculate Median when odd number of obesrvations:
#
# $$ ({\frac{n+1}{2}})^{th} term$$
#
#
# > The Formula to Calculate Median when Even Number of Observations:
#
# $$ \frac{[ (\,{\frac{n}{2}}) \,^{th}term + \{( \,{\frac{n}{2}}) \, + 1\}^{th}term] \,}{2}$$
# > calculate Median Using Numpy Libraries
# ``` python
# np.median(Data['Mthly_HH_Expense'], axis=0)
# ```
# * 15500.0
#
# >calualte Median Using Pandas Libraries
# ``` python
# Data.median(axis=0)
# ```
# ### Result
# | ID | Label | Mean |
# | --- | --- | --- |
# | 1 | Mthly_HH_Income | 35000.0 |
# | 2 | Mthly_HH_Expense | 15500.0|
# | 3 | No_of_Fly_Members | 4.0 |
# | 4 | Emi_or_Rent_Amt | 0.0 |
# | 5 | Annual_HH_Income | 447420.0 |
# | 6 | No_of_Earning_Members | 1.0 |
# dtype: float64

# %% [markdown]
# ##**3. Mode**
#
# The mode is the value that occurs most
# often. A dataset can have 0 modes, 1
# mode or multiple modes
# >Calculate mode using pandas:
# ```python
# Data.mode(Data,axis=0)
# ```
# ### Results
# |index|Mthly\_HH\_Income|Mthly\_HH\_Expense|No\_of\_Fly\_Members|Emi\_or\_Rent\_Amt|Annual\_HH\_Income|Highest\_Qualified\_Member|No\_of\_Earning\_Members|
# |---|---|---|---|---|---|---|---|
# |0|45000|25000|4|0|590400|Graduate|1|
#
# >Calculate mode using Scipy.stats:
# ```python
# mode = stats.mode(Data,axis = 0)
# print('Mode : ', mode[0][0])
# print('Count : ',mode[1][0])
# ```
#
# >Mode :  [45000 25000 4 0 590400 'Graduate' 1]
#
# >Count :  [ 4  8 15 30  2 19 33]

# %% [markdown]
# ## **4. Variance**
# The variance is a measure of variability. It is calculated by taking the average of squared deviations from the mean.
#
# Variance tells you the degree of spread in your data set.The more spread the data, the larger the variance is in relation to the mean.
# ***
# $Sample \ Variance \ Formula:$
# $$s^2= \dfrac{\sum (X - \bar{x})^2}{n - 1}$$
# $Explanation$
# $$s^2 = sample \ variance$$
# $$\sum = sum \ of…$$
# $$Χ = each \ value$$
# $$\bar{x} = sample \ mean$$
# $$n = number \ of \ values \ in \ the \ sample$$
#
# >Example code in python :
#
#  ```python
# def calculate_mean(numbers):
#   s= sum(numbers)
#   n = len(numbers)
#   mean = s/n
#   return mean
# #finding difference from the mean
# def find_difference(numbers):
#   #find the mean
#   mean = calculate_mean(numbers)
#   #find the difference from the mean
#   diff = []
#   for num in numbers:
#     diff.append(num-mean)
#   return diff
# def calculate_variance(numbers):
#   #find the list of differences
#   diff = find_difference(numbers)
#   #find the squared differences
#   squared_diff = []
#   for d in diff:
#     squared_diff.append(d ** 2)
#     #find the variance
#     sum_squared_diff = sum(squared_diff)
#     variance = sum_squared_diff/len(numbers)
#   return variance
# if __name__== '__main__':
#   income = Data['Mthly_HH_Income']
#   variance = calculate_variance(income)
#   print(f"The variance of Income is {variance}")
#  ```
#  >output :
#  ```python
# The variance of Income is 667478836.0
#  ```
#
# >Calculate Variance using python libraies :
# ```python
# np.var(Data)
# Data.var(axis=None)
# output :
# Mthly_HH_Income          6.811009e+08
# Mthly_HH_Expense         1.461733e+08
# No_of_Fly_Members        2.302449e+00
# Emi_or_Rent_Amt          3.895551e+07
# Annual_HH_Income         1.024869e+11
# No_of_Earning_Members    5.391837e-01
# dtype: float64
# ```

# %% [markdown]
# ## **5.Standard deviation**
# Standard deviation is the measurement of the average distance between each quantity and mean. That is, how data is spread out from the mean. A low standard deviation indicates that the data points tend to be close to the mean of the data set, while a high standard deviation indicates that the data points are spread out over a wider range of values.
#
# $Sample \ Variance \ Formula:$
# $$S.D = \sqrt{\dfrac{1}{N - 1}\sum^{N}_{i=1} (x_{i} - \bar{x})^2}$$
# $Explanation$
# $$S.D = sample \ standard \ deviation$$
# $$\sum = sum \ of…$$
# $$Χ = each \ value$$
# $$\bar{x} = sample \ mean$$
# $$N = number \ of \ values \ in \ the \ sample$$
# $$ i = 1,2,3,4,5....N $$
#
# >Standard Deviation code in Python :
#
# ```python
# def calculate_mean(numbers):
#   s= sum(numbers)
#   n = len(numbers)
#   mean = s/n
#   return mean
# # finding difference from the mean
# def find_difference(numbers):
#   #find the mean
#   mean = calculate_mean(numbers)
#   #find the difference from the mean
#   diff = []
#   for num in numbers:
#     diff.append(num-mean)
#   return diff
# def calculate_variance(numbers):
#   #find the list of differences
#   diff = find_difference(numbers)
#   #find the squared differences
#   squared_diff = []
#   for d in diff:
#     squared_diff.append(d ** 2)
#     #find the variance
#     sum_squared_diff = sum(squared_diff)
#     variance = sum_squared_diff/len(numbers)
#   return variance
#
#   #calculate standard deviation
# def standard_deviation(numbers):
#   var = calculate_variance(numbers)
#   return math.sqrt(var)
#
# if __name__== '__main__':
#   income = Data['Mthly_HH_Income']
#   std = standard_deviation(income)
#   print(f"The Standard Deviation of Income is {std}")
# ```
#
# ```python
# output :
#
# The Standard Deviation of Income is 25835.611779092826
# ```
# >findout Standard Deviation using Python Libraries :
# ```python
# np.var(Data)
# Data.var(axis=None)
# ```
#
# >output :
# ```
# label                      Std
# Mthly_HH_Income           26097.908979
# Mthly_HH_Expense          12090.216824
# No_of_Fly_Members             1.517382
# Emi_or_Rent_Amt            6241.434948
# Annual_HH_Income         320135.792123
# No_of_Earning_Members         0.734291
# dtype: float64
# ```

# %% [markdown]
# ## **6.Correlation**
# Correlation is a measure of the joint variability of two variables.
# Unlike covariance, correlation could be thought of as a
# standardized measure. It takes on values between -1 and 1, thus
# it is easy for us to interpret the result
# >Sample correlation formula :
# $$ r = \frac{𝑠_{𝑥𝑦}}{𝑠_{𝑥}s_{y}}$$
#
# ![Alt Text](https://editor.analyticsvidhya.com/uploads/39170Formula.JPG "correlation")
#
# If r is close to 0, it means there is no relationship between the variables. If r is positive, it means that as one variable gets larger the other gets larger. If r is negative it means that as one gets larger, the other gets smaller (often called an “inverse” correlation).
#
# ![Alt Text](https://miro.medium.com/max/716/1*P5L0g1YjeRZchbJiFll-0g.jpeg "correlation")
#
# ### Coding Example :
# ```python
# plt.figure(figsize=(5,5))
# sns.heatmap(df.corr(), cbar=True, fmt='.1f', annot=True, cmap='Blues')
# plt.title('Correlation of Data')
# plt.savefig('Correlation Heat map')
# ```
#
# **output :**
#
# ![](https://drive.google.com/uc?export=view&id=17qOWqQt-9ZHkno7pyeauWByJqZIOAuGB)

# %% [markdown]
# ##**7.Normal Distribution**
# In statistics, a normal distribution (also known as Gaussian, Gauss, or Laplace–Gauss distribution) is a type of continuous probability distribution for a real-valued random variable.
#
# **Formula :**
#
# ![Alt Text](https://lh5.googleusercontent.com/1PRv7o2FM7c50ioR5ZIz33lrpkprwmC46yZr6EAYblOQvbwV9j6XVWdD_ZvqJ-Qhc7lOZIC648kHo1hV_hWqpIrRqi6ghf_IqN9ViDwZv4skWUYf1C-R5cDS--5_ckOlYKopTeS1 "normal distribution")
#
# $f(x)	=	probability \ density \ function$
#
# $\sigma	=	standard \ deviation$
#
# $\mu	=	mean$
#
# $\pi = 3.14$
#
# $e = 2.71$
#
# We call this Bell-shaped curve a Normal Distribution.
#
# ![Alt Text](https://t4.ftcdn.net/jpg/04/03/54/91/360_F_403549199_xr1XSHKGt33amAnaVunIl43kAiKt2fRp.jpg "normal distribution")
#
# ###coding Example :
# ```python
# #every column in the dataframe stored in var_group
# var_group = data.columns
# size = len(var_group)
# plt.figure(figsize = (7*size,3), dpi = 400)
#
# #looping for each variable
# for j,i in enumerate(var_group):
#   # calculating descriptives of variable
#     mini = data[i].min()
#     maxi = data[i].max()
#     ran = data[i].max()-data[i].min()
#     mean = data[i].mean()
#     median = data[i].median()
#     st_dev = data[i].std()
#     skew = data[i].skew()
#
#     # calculating points of standard deviation
#     points = mean-st_dev, mean+st_dev
#
#     #Plotting the variable with every information
#     plt.subplot(1,size,j+1)
#     sns.distplot(data[i],hist=True, kde=True)
#
#     sns.lineplot(points, [0,0], color = 'black', label = "std_dev")
#     sns.scatterplot([mini,maxi], [0,0], color = 'orange', label = "min/max")
#     sns.scatterplot([mean], [0], color = 'red', label = "mean")
#     sns.scatterplot([median], [0], color = 'blue', label = "median")
#     plt.xlabel('{}'.format(i), fontsize = 20)
#     plt.ylabel('density')
#     plt.title('std_dev = {}; \nskew = {}; range = {}\nmean = {}; median = {}'.format((round(points[0],2),round(points[1],2)),
#
#                                                                                                     round(skew,2),
#                                                                                                     (round(mini,2),round(maxi,2),round(ran,2)),
#                                                                                                     round(mean,2),
#                                                                                                     round(median,2)))
# ```
# **output :**
#
# ![image](https://drive.google.com/uc?export=view&id=1lqN43KaosjTp5SpFZ5zaKd75eHECP1ms)
# ![image](https://drive.google.com/uc?export=view&id=1j0bd7T0w4FEdHngQxAprRE4tVcO9JrOs)
# ![image](https://drive.google.com/uc?export=view&id=19sy4fZ3VG37Q2L82YO7u1Hg1g8OsWjiZ)

# %% [markdown]
# ## **8.Feature of Normal Distribution**
# All forms of the normal distribution share the following characteristics:
#
# 1.It is symmetric
#
# * The shape of the normal distribution is perfectly symmetrical.
# * This means that the curve of the normal distribution can be divided from the middle and we can produce two equal halves. Moreover, the symmetric shape exists when an equal number of observations lie on each side of the curve.
#
# 2.The mean, median, and mode are equal
#
# * The midpoint of normal distribution refers to the point with maximum frequency i.e., it consists of most observations of the variable.
# * The midpoint is also the point where all three measures of central tendency fall. These measures are usually equal in a perfectly shaped normal distribution.
#
# ![Alt Text](https://1investing.in/wp-content/uploads/2019/05/who-actually-found-the-bell-curve_1.jpeg "normal distribution")
#
# 3.Empirical rule
#
# * In normally distributed data, there is a constant proportion of data points lying under the curve between the mean and a specific number of standard deviations from the mean.
# * Thus, for a normal distribution, almost all values lie within 3 standard deviations of the mean.
# * These check buttons of normal distribution will help you realize the appropriate percentages of the area under the curve.
# * Remember that this empirical rule applies to all normal distributions. Also, note that these rules are applied only to the normal distributions.
# ![Alt Text](https://www.isixsigma.com/wp-content/uploads/2018/11/Screen-Shot-2022-06-13-at-10.20.58-AM.png "normal distribution")
#
# 4.Skewness and kurtosis
#
# * Skewness and kurtosis are coefficients that measure how different the distribution is from a normal distribution.
# * It measures the symmetry of the normal distribution while kurtosis measures the thickness of the tail distribution relative to that of normal distribution.
#
# 5.Area under the curve
#
# * The total area under the curve is unity(=1)
#
# One more important phenomena of a normal distribution is that it retains the normal shape throughout, unlike other probability distributions that change their properties after a transformation. For a Normal Distribution:
#
# Product of two Normal Distribution results into a Normal Distribution
# The Sum of two Normal Distributions is a Normal Distribution
# Convolution of two Normal Distribution is also a Normal Distribution
# Fourier Transformation of a Normal Distribution is also Normal

# %% [markdown]
# ## **9.Positively Skewed & Negatively Skewed Normal Distribution**
# **Skew :** Skewness is a measure of asymmetry that indicates whether
# the observations in a dataset are concentrated on one side.
#
# * Normal Distribution is symmetric, which means its tails on one side are the mirror image of the other side. But this is not the case with most datasets. Generally, data points cluster on one side more than the other. We call these types of distributions Skewed Distributions
#
# ![image](https://drive.google.com/uc?export=view&id=1LIHcvaLBb7WV0m07DdfIuJxrP-Rr4qJ3)

# %% [markdown]
# ### **9.1 Positively Skewed**
# * When data points cluster on the left side of the distribution, then the tail would be longer on the right side. This is the property of Right Skewed Distribution. Here, the tail is longer in the positive direction so we also call it Positively Skewed Distribution.
#
#
# ![Alt Text](https://www.datavedas.com/wp-content/uploads/2017/12/1.1.1.4-Measures-of-Shape-7-1-768x461.png "positively Skewed")

# %% [markdown]
# ###**9.2 Negatively Skewed**
# * When data points cluster on the right side of the distribution, then the tail would be longer on the left side. This is the property of Left Skewed Distribution. The tail is longer in the negative direction so we also call it Negatively Skewed Distribution.
#
#
# ![Alt Text](https://www.datavedas.com/wp-content/uploads/2017/12/1.1.1.4-Measures-of-Shape-8.png "positively Skewed")

# %% [markdown]
# ##**10. Effect on Mean, Median and Mode due to Skewness**
# 1. In the Normal Distribution, Mean, Median and Mode are equal
# $$Mean = Median = Mode$$
#
# 2. In negatively skewed distribution:
# * When the curve is negatively skewed, we expect that the mode has the largest value followed by the median and then the mean.
# $$Mode > Median > Mean$$
#
# 3. In positively skewed distribution:
# * when the shape of the distribution is positively skewed, the mean has the highest value followed by the median and then the mode.
# $$Mode < Median < Mean$$
#
# ![Alt Text](https://www.storyofmathematics.com/wp-content/uploads/2022/02/interpreting-the-skewness-of-a-distribution_s-shape.png "positively Skewed")

# %% [markdown]
# ##**11. Explain QQ Plot and show the implementation of the same**
# >Quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities or dividing the observations in a sample in the same way.
#
# * 2 quantile is known as the Median
# * 4 quantile is known as the Quartile
# * 10 quantile is known as the Decile
# * 100 quantile is known as the Percentile
#
# ![Alt Text](https://i.stack.imgur.com/ZXRkL.png "QQ Plot")
#
# Implementation:
# ```python
# #every column in the dataframe stored in var_group
# var_group = df.columns
# size = len(var_group)
# plt.figure(figsize = (7*size,3), dpi = 400)
#
# #looping for each variable
# for j,i in enumerate(var_group):
# #Plotting the variable with every information
#   sm.qqplot(df[i],line='45',fit=True,dist=stats.norm)
#   plt.xlabel('{}'.format(i), fontsize = 20)
#   plt.ylabel('Density')
# ```
#
# output:
#
# ![](https://drive.google.com/uc?export=view&id=1Fhkvuei47_P-vfFGXa2MXN-TGEhy5SND)
# ![](https://drive.google.com/uc?export=view&id=1XUdRgBL68O8IEXTWFzkN3KdlQM2SLzlI)
# ![](https://drive.google.com/uc?export=view&id=1eqGj8saKIiLRtguMO-1b7xD542RDZuQE)

# %% [markdown]
# ## **12. Explain Box Cox and show the implementation of the same**
# **Definition :** The statisticians George Box and David Cox developed a procedure to identify an appropriate exponent (Lambda = l) to use to transform data into a “normal shape.”
# The Lambda value indicates the power to which all data should be raised. In order to do this, the Box-Cox power transformation searches from λ = -5 to λ = +5 until the best value is found.
# A value of  λ is said to be best if it is able to approximate the non-normal curve to a normal curve.
#
# **Formula :**
#
# ![Alt Text](https://www.statisticshowto.com/wp-content/uploads/2015/07/boxcox-formula2.png "Box-COX")
#
# This function requires input to be positive. Using this formula manually is a very laborious task thus many popular libraries provide this function.
#
# **use Box-cox Transformation,when :**
# * The process Data is not Normally Distributed and Data is not Collected in Sub Groups.
# * Residuals are not Normally distributed and they Don't have constant variance
# * All values must be greater than 0(Zero).
# * Data must be for Continous variable.
#
# **In Regression Analysis :**
# * under most conditions,it is not necessary to correct for non-normality unless the data are highly skewed.
# * select the lambda value(λ)that minitab uses to transform the data:
#  * **No tranformation :** use your original response Data.
#  * **optimal Lambda :** use the optimal lambda, which should produce the best fitting transformation.
# By default, minitab rounds the optimal lambda to 0.5 or the nearest integer.
#
# **for example, minitab rounds lambda to -1,-0.5,0,0.5,1 etc..,**
# * **λ = 0(natural log) :** Use the natural log of your Data
# * **λ=0.5(square root) :**Use the Square rrot of your Data
# * **λ :**Use a Specified value for lambda.
#  * other common transformations are Square(λ = 2),inverse Square root(λ = -0.5) and inverse(λ = -1) *
#
#  **Usally,you should not use a value outside the range of -5 and 5.**
#
#
# ![Alt Text](https://i.stack.imgur.com/gx7Sy.png "Box-COX")
#
# ![Alt Text](https://www.isixsigma.com/wp-content/uploads/2010/02/Example-Box-Cox-Plot-of-Data.gif "Box-COX")
#
# * For the Box-Cox transformation, a λ value of 1 equivalent to using the original Data.Therefore, if the confidence interval for the optimal λ includes 1,then **no value transformation is necessary**
# * In this example, the 95% confidence interval for λ(-2.48 to 0.69) does not include 1,so a transformation is appropriate.
# * The estimated value for the optimal λ is -1.53.
#
#
#
# **Implementation :**SciPy’s stats package provides a function called boxcox for performing box-cox power transformation that takes in original non-normal data as input and returns fitted data along with the lambda value that was used to fit the non-normal distribution to normal distribution. Following is the code for the same.
#
# example 1:
# ```python
# # transform training data & save lambda value
# fitted_data, fitted_lambda = stats.boxcox(df['Mthly_HH_Income'])
#
#
#
# # creating axes to draw plots
# fig, ax = plt.subplots(1, 2)
#
# # plotting the original data(non-normal) and
# # fitted data (normal)
# sns.distplot(df['Mthly_HH_Income'], hist = False, kde = True,
#             kde_kws = {'shade': True, 'linewidth': 2},
#             label = "Non-Normal", color ="green", ax = ax[0])
#
# sns.distplot(fitted_data, hist = False, kde = True,
#             kde_kws = {'shade': True, 'linewidth': 2},
#             label = "Normal", color ="green", ax = ax[1])
#
# # adding legends to the subplots
# plt.legend(loc = "upper right")
#
# # rescaling the subplots
# fig.set_figheight(5)
# fig.set_figwidth(10)
#
# print(f"Lambda value used for Transformation: {fitted_lambda}")
# ```
# ![](https://drive.google.com/uc?export=view&id=1Zr9Eke6rjaqSNb7LMChIUmpmDqHary2t)
#
# example 2
# ```python
# # transform training data & save lambda value
# fitted_data, fitted_lambda = stats.boxcox(df['Mthly_HH_Expense'])
# # creating axes to draw plots
# fig, ax = plt.subplots(1, 2)
#
# #plotting the original data(non-normal) and fitted data (normal)
#
# sns.distplot(df['Mthly_HH_Expense'], hist = False, kde = True,
#               kde_kws = {'shade': True, 'linewidth': 2},
#                label = "Non-Normal", color ="green", ax = ax[0])
#
# sns.distplot(fitted_data, hist = False, kde = True,
#               kde_kws = {'shade': True, 'linewidth': 2},
#               label = "Normal", color ="green", ax = ax[1])
#
# # adding legends to the subplots
# plt.legend(loc = "upper right")
#
# # rescaling the subplots
# fig.set_figheight(5)
# fig.set_figwidth(10)
#
# print(f"Lambda value used for Transformation: {fitted_lambda}")
# ```
#
# ![](https://drive.google.com/uc?export=view&id=11uqiy7bJFDrs6oO5QJ3nsHmt35RNtaIy)
